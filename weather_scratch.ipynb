# %%
from noaa.noaa_snowflake import get_noaa_weather_data

# %%
data = get_noaa_weather_data()

# %%
data["Average daily wind speed"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
data.pivot(index="DATE", columns="VARIABLE_NAME", values="VALUE")
# Out:
# VARIABLE_NAME  Average daily wind speed  Maximum temperature
# DATE
# 2000-01-01                          3.1                 25.6
# 2000-01-02                          5.1                 27.2
# 2000-01-03                          4.8                 24.4
# 2000-01-04                          4.8                 14.4
# 2000-01-05                          3.1                 14.4
# ...                                 ...                  ...
# 2026-06-08                          4.6                 32.8
# 2026-06-09                          4.2                 32.8
# 2026-06-10                          4.7                 33.3
# 2026-06-11                          5.2                 33.9
# 2026-06-12                          2.4                 33.3
#
# [9660 rows x 2 columns]
