# %%
from noaa.noaa_snowflake import get_noaa_weather_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from noaa.noaa_snowflake import get_noaa_weather_data
#
# File c:\Users\andre\Source\modo_energy\noaa\noaa_snowflake.py:2
#       1 import snowflake.connector
# ----> 2 from snowflake_credentials import (
#       3     ACCOUNT,
#       4     DATABASE,
#       5     ROLE,
#       6     SCHEMA,
#       7     TOKEN,
#       8     USER,
#       9     WAREHOUSE,
#      10 )
#      13 def get_noaa_weather_data():
#      14     """Fetch NOAA weather data from Snowflake."""
#
# ModuleNotFoundError: No module named 'snowflake_credentials'

# %%
data = get_noaa_weather_data()
